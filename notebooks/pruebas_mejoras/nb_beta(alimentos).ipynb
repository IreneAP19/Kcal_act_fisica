# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time

# Initialize WebDriver
driver = webdriver.Chrome()  # You should replace this with the appropriate web driver you're using (Chrome, Firefox, etc.)

# Open the URL of the webpage
url="https://recetasdecocina.elmundo.es/tabla-calorias"
driver.get(url)

# Automatically scroll the page
scroll_pause_time = 2  # Pause between each scroll
screen_height = driver.execute_script("return window.screen.height;")  # Browser window height
i = 1
while True:
    # Scroll down
    driver.execute_script(f"window.scrollTo(0, {screen_height * i});")
    i += 1
    time.sleep(scroll_pause_time)

    # Check if reaching the end of the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")
    if screen_height * i > scroll_height:
        break

# Fetch the data using BeautifulSoup after all data is loaded
soup = BeautifulSoup(driver.page_source, "html.parser")
# Process and save the data as needed

# Close the WebDriver session
driver.quit()

# %%
table = soup.find("table")
    
    # Extraer filas de la tabla
rows = table.find_all("tr")

# %%
import pandas as pd

# %%
tables = soup.find_all("table")

# %%
tablas=["verduras","Frutas","Frutos_secos","Lacteos","Carnes","Pescados","Dulces","Cereales","Legumbres","huevos","Pasteles","Bebidas","Aceites","Salsas"]

# %%
data = []
for i in range(len(tablas)):
    rows = tables[i].find_all("tr")
    

    for row in rows:
        cols = row.find_all("td")
        cols = [col.text.strip() for col in cols]  # Extraer texto de cada celda
        
        # Filtrar categorías que están en negrita y solo tienen una columna
        if len(cols) == 2:  
            data.append(cols)

# %%
df=pd.DataFrame(data)

# %%
indices_corte = df.index[df[1] == "CALORÍAS por cada 100 gramos"].tolist()
dfs_dict = {}

# Iterar sobre los índices y crear subconjuntos
for i in range(len(indices_corte) - 1):
    inicio = indices_corte[i]
    fin = indices_corte[i + 1] - 1  # -1 para evitar solapamiento
    
    nombre = tablas[i]  # Obtener el nombre correspondiente
    dfs_dict[nombre] = df.loc[inicio:fin, :]  # Crear el subconjunto

# Guardar cada DataFrame en un archivo CSV con su nombre
for nombre, sub_df in dfs_dict.items():
    #sub_df.to_csv(f"{nombre}.csv", index=False)
    print(f"✅ {nombre}.csv guardado con {len(sub_df)} filas.")
# Out:
# ✅ verduras.csv guardado con 44 filas.
# ✅ Frutas.csv guardado con 37 filas.
# ✅ Frutos_secos.csv guardado con 8 filas.
# ✅ Lacteos.csv guardado con 39 filas.
# ✅ Carnes.csv guardado con 50 filas.
# ✅ Pescados.csv guardado con 37 filas.
# ✅ Dulces.csv guardado con 12 filas.
# ✅ Cereales.csv guardado con 22 filas.
# ✅ Legumbres.csv guardado con 4 filas.
# ✅ huevos.csv guardado con 5 filas.
# ✅ Pasteles.csv guardado con 12 filas.
# ✅ Bebidas.csv guardado con 33 filas.
# ✅ Aceites.csv guardado con 6 filas.

# %%
dfs_dict
# Out:
# {'verduras':                                0                             1
#  0          VERDURAS Y HORTALIZAS  CALORÍAS por cada 100 gramos
#  1               Aceitunas negras                           349
#  2               Aceitunas verdes                           132
#  3                        Acelgas                            33
#  4                           Ajos                           169
#  5                     Alcachofas                            64
#  6                           Apio                            20
#  7                      Berenjena                            29
#  8                         Berros                            21
#  9                        Brócoli                            31
#  10                     Calabacín                            31
#  11                      Calabaza                            24
#  12                       Cebolla                            47
#  13                Cebolla tierna                            39
#  14       Champiñón y otras setas                            28
#  15                           Col                            28
#  16               Col de Bruselas                            54
#  17                      Coliflor                            30
#  18                       Endibia                            22
#  19                      Escarola                            37
#  20                    Espárragos                            26
#  21            Espárragos en lata                            24
#  22                      Espinaca                            32
#  23          Espinacas congeladas                            25
#  24                 Habas tiernas                            64
#  25                        Hinojo                            16
#  26                       Lechuga                            18
#  27                         Nabos                            29
#  28                 Papas cocidas                            86
#  29                        Pepino                            12
#  30                       Perejil                            55
#  31                      Pimiento                            22
#  32                Porotos verdes                            21
#  33                       Puerros                            42
#  34                       Rábanos                            20
#  35                     Remolacha                            40
#  36                       Repollo                            19
#  37                        Rúcula                            37
#  38               Soja, Brotes de                            50
#  39  Tomate triturado en conserva                            39
#  40                       Tomates                            22
#  41                         Trufa                            92
#  42                     Zanahoria                            42
#  43                Zumo de tomate                            21,
#  'Frutas':                   0                             1
#  44           FRUTAS  CALORÍAS por cada 100 gramos
#  45        Arándanos                            41
#  46            Caqui                            64
#  47           Cereza                            47
#  48        Chirimoya                            78
#  49          Ciruela                            44
#  50     Ciruela seca                           290
#  51             Coco                           646
#  52            Dátil                           279
#  53       Dátil seco                           306
#  54        Frambuesa                            40
#  55           Fresas                            36
#  56          Granada                            65
#  57         Grosella                            37
#  58            Higos                            80
#  59      Higos secos                           275
#  60             Kiwi                            51
#  61            Limón                            39
#  62        Mandarina                            40
#  63            Mango                            57
#  64          Manzana                            52
#  65            Melón                            31
#  66             Mora                            37
#  67          Naranja                            44
#  68        Nectarina                            64
#  69         Nísperos                            97
#  70           Papaya                            45
#  71             Pera                            61
#  72             Piña                            51
#  73  Piña en almíbar                            84
#  74          Plátano                            90
#  75           Pomelo                            30
#  76           Sandía                            30
#  77              Uva                            81
#  78         Uva pasa                           324
#  79    Zumo de fruta                            45
#  80  Zumo de Naranja                            42,
#  'Frutos_secos':                0                             1
#  81  FRUTOS SECOS  CALORÍAS por cada 100 gramos
#  82     Almendras                           620
#  83     Avellanas                           675
#  84      Castañas                           199
#  85          Maní                           560
#  86        Nueces                           660
#  87       Piñones                           660
#  88      Pistacho                           581,
#  'Lacteos':                               0                             1
#  89          LÁCTEOS Y DERIVADOS  CALORÍAS por cada 100 gramos
#  90                      Cuajada                            92
#  91                Flan de huevo                           126
#  92             Flan de vainilla                           102
#  93              Helados lácteos                           167
#  94    Leche condensada c/azúcar                           350
#  95    Leche condensada s/azúcar                           160
#  96               Leche de cabra                            72
#  97               Leche de oveja                            96
#  98             Leche descremada                            36
#  99    Leche en polvo descremada                           373
#  100       Leche en polvo entera                           500
#  101                Leche entera                            68
#  102       Leche semi descremada                            49
#  103                      Mousse                           177
#  104       Nata o crema de leche                           298
#  105      Queso blanco desnatado                            70
#  106                  Queso Brie                           263
#  107            Queso cammembert                           312
#  108               Queso cheddar                           381
#  109                 Queso crema                           245
#  110               Queso de bola                           349
#  111             Queso de Burgos                           174
#  112              Queso de oveja                           245
#  113                  Queso edam                           306
#  114              Queso emmental                           415
#  115       Queso fundido untable                           285
#  116               Queso gruyere                           391
#  117              Queso manchego                           376
#  118            Queso mozzarella                           245
#  119             Queso parmesano                           393
#  120                Queso ricota                           400
#  121             Queso roquefort                           405
#  122                    Requesón                            96
#  123             Yogur desnatado                            45
#  124  Yogur desnatado con frutas                            82
#  125  Yogur enriquecido con nata                            65
#  126               Yogur natural                            62
#  127     Yogur natural con fruta                           100,
#  'Carnes':                                0                             1
#  128     CARNES, CAZA Y EMBUTIDOS  CALORÍAS por cada 100 gramos
#  129      Bacon (Panceta ahumada)                           665
#  130             Butifarra cocida                           390
#  131  Butifarra, salchicha fresca                           326
#  132                      Cabrito                           127
#  133               Cerdo, chuleta                           330
#  134                Cerdo, hígado                           153
#  135                  Cerdo, lomo                           208
#  136                   Chicharrón                           601
#  137                      Chorizo                           468
#  138                       Ciervo                           120
#  139            Codorniz y perdiz                           114
#  140               Conejo, liebre                           162
#  141               Cordero lechón                           105
#  142               Cordero pierna                            98
#  143           Cordero, costillas                           215
#  144              Cordero, hígado                           132
#  145                       Faisán                           144
#  146                    Foie-Gras                           518
#  147                      Gallina                           369
#  148                  Hamburguesa                           230
#  149                       Jabalí                           107
#  150                        Jamón                           380
#  151                 Jamón cocido                           126
#  152                  Jamón crudo                           296
#  153                   Jamón York                           289
#  154               Lengua de vaca                           191
#  155               Lomo embuchado                           380
#  156                    Mortadela                           265
#  157                         Pato                           200
#  158                  Pavo, Muslo                           186
#  159                Pavo, Pechuga                           134
#  160                       Perdiz                           120
#  161                Pies de cerdo                           290
#  162                Pollo, Hígado                           129
#  163                 Pollo, Muslo                           186
#  164                        Pollo                           134
#  165                       Salami                           325
#  166          Salchicha Frankfurt                           315
#  167                   Salchichón                           294
#  168                      Ternera                           181
#  169             Ternera, chuleta                           168
#  170              Ternera, hígado                           140
#  171              Ternera, lengua                           207
#  172               Ternera, riñón                            86
#  173               Ternera, sesos                           125
#  174           Ternera, solomillo                           290
#  175                Tira de asado                           401
#  176                       Tripas                           100
#  177               Vacuno, Hígado                           129,
#  'Pescados':                                       0                             1
#  178     PESCADOS, CRUSTÁCEOS Y MARISCOS  CALORÍAS por cada 100 gramos
#  179                             Almejas                            50
#  180                             Anchoas                           175
#  181                            Anguilas                           200
#  182     Atún en lata con aceite vegetal                           280
#  183               Atún en lata con agua                           127
#  184                         Atún fresco                           225
#  185                      Bacalao fresco                            74
#  186                        Bacalao seco                           322
#  187                              Besugo                           118
#  188                             Caballa                           153
#  189                             Calamar                            82
#  190                            Cangrejo                            85
#  191                              Caviar                           233
#  192                             Congrio                           112
#  193                              Dorada                            80
#  194                               Gallo                            73
#  195                              Gambas                            96
#  196                            Langosta                            67
#  197                          Langostino                            96
#  198                            Lenguado                            73
#  199                              Lubina                           118
#  200                               Lucio                            81
#  201                            Mejillón                            74
#  202                             Merluza                            86
#  203                                Mero                           118
#  204                              Ostras                            80
#  205                            Pejerrey                            87
#  206                          Pez espada                           109
#  207                               Pulpo                            57
#  208                           Rodaballo                            81
#  209                              Salmón                           172
#  210                      Salmón ahumado                           154
#  211                           Salmonete                            97
#  212  Sardina en lata con aceite vegetal                           192
#  213                            Sardinas                           151
#  214                              Trucha                            94,
#  'Dulces':                                          0                             1
#  215                      AZÚCARES Y DULCES  CALORÍAS por cada 100 gramos
#  216                                 Azúcar                           380
#  217  Cacao en polvo con azúcar instantáneo                           366
#  218                              Caramelos                           378
#  219                    Chocolate con leche                           550
#  220                    Chocolate sin leche                           530
#  221          Crema chocolate con avellanas                           549
#  222                     Dulce de membrillo                           215
#  223                        Helados de agua                           139
#  224                  Mermeladas con azúcar                           280
#  225                  Mermeladas sin azúcar                           145
#  226                                   Miel                           300,
#  'Cereales':                                0                             1
#  227         CEREALES Y DERIVADOS  CALORÍAS por cada 100 gramos
#  228                 Arroz blanco                           354
#  229               Arroz integral                           350
#  230                        Avena                           367
#  231                       Cebada                           373
#  232                      Centeno                           350
#  233       Cereales con chocolate                           358
#  234  Cereales desayuno, con miel                           386
#  235                Copos de maíz                           350
#  236               Harina de maíz                           349
#  237     Harina de trigo integral                           340
#  238     Harina de trigo refinada                           353
#  239               Pan de centeno                           241
#  240          Pan de trigo blanco                           255
#  241        Pan de trigo integral                           239
#  242    Pan de trigo molde blanco                           233
#  243  Pan de trigo molde integral                           216
#  244               Pasta al huevo                           368
#  245              Pasta de sémola                           361
#  246                      Polenta                           358
#  247              Sémola de trigo                           368
#  248                         Yuca                           338,
#  'Legumbres':              0                             1
#  249  LEGUMBRES  CALORÍAS por cada 100 gramos
#  250  Garbanzos                           361
#  251     Judías                           343
#  252   Lentejas                           336,
#  'huevos':                 0                             1
#  253        HUEVOS  CALORÍAS por cada 100 gramos
#  254         Clara                            48
#  255    Huevo duro                           147
#  256  Huevo entero                           162
#  257          Yema                           368,
#  'Pasteles':                                           0                             1
#  258                              PASTELERÍA  CALORÍAS por cada 100 gramos
#  259                                Bizcocho                           456
#  260                     Croissant chocolate                           469
#  261                        Croissant, donut                           456
#  262                   Galletas de chocolate                           524
#  263  Galletas de mantequilla tipo “Danesas”                           397
#  264                        Galletas saladas                           464
#  265                              Magdalenas                           469
#  266                Pasta de hojaldre cocida                           565
#  267                       Pastel de manzana                           311
#  268        Pastel de manzana, masa hojaldre                           456
#  269                         Pastel de queso                           414,
#  'Bebidas':                                        0                             1
#  270                              BEBIDAS  CALORÍAS por cada 100 gramos
#  271                        Agua ardiente                           280
#  272                          Agua tónica                            34
#  273                                 Anís                           312
#  274               Batido lácteo de cacao                           100
#  275  Cacao en polvo sin azúcar a la taza                           439
#  276                                 Café                             1
#  277                        Cerveza negra                            37
#  278                        Cerveza rubia                            45
#  279                    Champaña demi-sec                            90
#  280                       Champaña dulce                           118
#  281                        Champaña seca                            85
#  282                        Coñac, brandy                           243
#  283                       Crema de cacao                           260
#  284                             Daiquiri                           122
#  285                         Gin & Tónica                            76
#  286                              Ginebra                           244
#  287                   Leche de almendras                           335
#  288                        Licor de caña                           273
#  289                          Piña colada                           194
#  290                                Pisco                           210
#  291               Refrescos carbonatados                            48
#  292                                  Ron                           244
#  293                          Sidra dulce                            33
#  294                           Sidra seca                            35
#  295                                   Té                             1
#  296                      Vermouth amargo                           112
#  297                       Vermouth dulce                           160
#  298                         Vino de mesa                            70
#  299                    Vino dulce, jerez                           160
#  300                          Vino oporto                           160
#  301                                Vodka                           315
#  302                               Whisky                           244,
#  'Aceites':                      0                             1
#  303   ACEITES Y GRASAS  CALORÍAS por cada 100 gramos
#  304  Aceite de girasol                           900
#  305    Aceite de oliva                           900
#  306            Manteca                           670
#  307        Mantequilla                           752
#  308  Margarina vegetal                           752}

# %%
filas = []
for categoria, df in dfs_dict.items():
    # Eliminar la primera fila porque no es un alimento real
    df_limpio = df.iloc[1:].copy()

    # Renombrar columnas para mayor claridad
    df_limpio.columns = ["alimento", "kcal"]

    # Agregar la categoría a cada fila
    df_limpio["categoria"] = categoria

    # Convertir kcal a tipo numérico (puede estar como string)
    df_limpio["kcal"] = pd.to_numeric(df_limpio["kcal"], errors="coerce")

    # Guardar filas
    filas.append(df_limpio)

# Unir todas las categorías en un solo DataFrame
df_alimentos = pd.concat(filas, ignore_index=True)

df_alimentos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   alimento   296 non-null    object
#  1   kcal       296 non-null    int64
#  2   categoria  296 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 7.1+ KB

# %%
rows = tables[0].find_all("tr")
data = []

for row in rows:
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]  # Extraer texto de cada celda
    
    # Filtrar categorías que están en negrita y solo tienen una columna
    if len(cols) == 2:  
        data.append(cols)
verduras = pd.DataFrame(data, columns=["Alimento", "Calorías por 100g"])
verduras.drop(0,inplace=True)
verduras["Calorías por 100g"]=verduras["Calorías por 100g"].astype(int)

# %%
rows = tables[1].find_all("tr")
data = []

for row in rows:
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]  # Extraer texto de cada celda
    
    # Filtrar categorías que están en negrita y solo tienen una columna
    if len(cols) == 2:  
        data.append(cols)
frutas = pd.DataFrame(data, columns=["Alimento", "Calorías por 100g"])
frutas.drop(0,inplace=True)
frutas["Calorías por 100g"]=frutas["Calorías por 100g"].astype(int)

# %%
rows = tables[2].find_all("tr")
data = []

for row in rows:
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]  # Extraer texto de cada celda
    
    # Filtrar categorías que están en negrita y solo tienen una columna
    if len(cols) == 2:  
        data.append(cols)
Frutos_secos = pd.DataFrame(data, columns=["Alimento", "Calorías por 100g"])
Frutos_secos.drop(0,inplace=True)
Frutos_secos["Calorías por 100g"]=Frutos_secos["Calorías por 100g"].astype(int)

# %%
rows = tables[3].find_all("tr")
data = []

for row in rows:
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]  # Extraer texto de cada celda
    
    # Filtrar categorías que están en negrita y solo tienen una columna
    if len(cols) == 2:  
        data.append(cols)
Lacteos= pd.DataFrame(data, columns=["Alimento", "Calorías por 100g"])
Lacteos.drop(0,inplace=True)
Lacteos["Calorías por 100g"]=Lacteos["Calorías por 100g"].astype(int)

# %%
rows = tables[4].find_all("tr")
data = []

for row in rows:
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]  # Extraer texto de cada celda
    
    # Filtrar categorías que están en negrita y solo tienen una columna
    if len(cols) == 2:  
        data.append(cols)
Carnes= pd.DataFrame(data, columns=["Alimento", "Calorías por 100g"])
Carnes.drop(0,inplace=True)
Carnes["Calorías por 100g"]=Carnes["Calorías por 100g"].astype(int)

# %%
rows = tables[5].find_all("tr")
data = []

for row in rows:
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]  # Extraer texto de cada celda
    
    # Filtrar categorías que están en negrita y solo tienen una columna
    if len(cols) == 2:  
        data.append(cols)
Pescados= pd.DataFrame(data, columns=["Alimento", "Calorías por 100g"])
Pescados.drop(0,inplace=True)
Pescados["Calorías por 100g"]=Pescados["Calorías por 100g"].astype(int)

# %%
rows = tables[6].find_all("tr")
data = []

for row in rows:
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]  # Extraer texto de cada celda
    
    # Filtrar categorías que están en negrita y solo tienen una columna
    if len(cols) == 2:  
        data.append(cols)
Dulces= pd.DataFrame(data, columns=["Alimento", "Calorías por 100g"])
Dulces.drop(0,inplace=True)
Dulces["Calorías por 100g"]=Dulces["Calorías por 100g"].astype(int)

# %%
rows = tables[13].find_all("tr")
data = []

for row in rows:
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]  # Extraer texto de cada celda
    
    # Filtrar categorías que están en negrita y solo tienen una columna
    if len(cols) == 2:  
        data.append(cols)
Salsas= pd.DataFrame(data, columns=["Alimento", "Calorías por 100g"])
Salsas.drop(0,inplace=True)
Salsas["Calorías por 100g"]=Salsas["Calorías por 100g"].astype(int)

# %%
rows = tables[12].find_all("tr")
data = []

for row in rows:
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]  # Extraer texto de cada celda
    
    # Filtrar categorías que están en negrita y solo tienen una columna
    if len(cols) == 2:  
        data.append(cols)
Aceites= pd.DataFrame(data, columns=["Alimento", "Calorías por 100g"])
Aceites.drop(0,inplace=True)
Aceites["Calorías por 100g"]=Aceites["Calorías por 100g"].astype(int)

# %%
rows = tables[11].find_all("tr")
data = []

for row in rows:
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]  # Extraer texto de cada celda
    
    # Filtrar categorías que están en negrita y solo tienen una columna
    if len(cols) == 2:  
        data.append(cols)
Bebidas= pd.DataFrame(data, columns=["Alimento", "Calorías por 100g"])
Bebidas.drop(0,inplace=True)
Bebidas["Calorías por 100g"]=Bebidas["Calorías por 100g"].astype(int)

# %%
rows = tables[10].find_all("tr")
data = []

for row in rows:
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]  # Extraer texto de cada celda
    
    # Filtrar categorías que están en negrita y solo tienen una columna
    if len(cols) == 2:  
        data.append(cols)
Pasteles= pd.DataFrame(data, columns=["Alimento", "Calorías por 100g"])
Pasteles.drop(0,inplace=True)
Pasteles["Calorías por 100g"]=Pasteles["Calorías por 100g"].astype(int)

# %%
rows = tables[9].find_all("tr")
data = []

for row in rows:
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]  # Extraer texto de cada celda
    
    # Filtrar categorías que están en negrita y solo tienen una columna
    if len(cols) == 2:  
        data.append(cols)
huevos= pd.DataFrame(data, columns=["Alimento", "Calorías por 100g"])
huevos.drop(0,inplace=True)
huevos["Calorías por 100g"]=huevos["Calorías por 100g"].astype(int)

# %%
rows = tables[8].find_all("tr")
data = []

for row in rows:
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]  # Extraer texto de cada celda
    
    # Filtrar categorías que están en negrita y solo tienen una columna
    if len(cols) == 2:  
        data.append(cols)
Legumbres= pd.DataFrame(data, columns=["Alimento", "Calorías por 100g"])
Legumbres.drop(0,inplace=True)
Legumbres["Calorías por 100g"]=Legumbres["Calorías por 100g"].astype(int)

# %%
rows = tables[7].find_all("tr")
data = []

for row in rows:
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]  # Extraer texto de cada celda
    
    # Filtrar categorías que están en negrita y solo tienen una columna
    if len(cols) == 2:  
        data.append(cols)
Cereales= pd.DataFrame(data, columns=["Alimento", "Calorías por 100g"])
Cereales.drop(0,inplace=True)
Cereales["Calorías por 100g"]=Cereales["Calorías por 100g"].astype(int)

# %% [markdown]
# -----------------------------

# %% [markdown]
# Dividimos los grupos de alimentos por categorias (según comida en la que debe estar y el macronutriente predominante)

# %%
df_alimentos["categoria"].unique()
# Out:
# array(['verduras', 'Frutas', 'Frutos_secos', 'Lacteos', 'Carnes',
#        'Pescados', 'Dulces', 'Cereales', 'Legumbres', 'huevos',
#        'Pasteles', 'Bebidas', 'Aceites'], dtype=object)

# %%
categorias_ref = pd.DataFrame({
    "categoria": [
        "verduras", "Frutas", "Frutos_secos", "Lacteos", "Carnes",
        "Pescados", "Dulces", "Cereales", "Legumbres", "huevos",
        "Pasteles", "Bebidas", "Aceites"
    ],
    "macronutriente": [
        "CH", "CH", "Grasa", "Proteína", "Proteína",
        "Proteína", "CH", "CH", "Proteína", "Proteína",
        "CH", "CH", "Grasa"
    ],
    "momento": [
        "Comida", "Desayuno", "Merienda", "Desayuno", "Comida",
        "Comida", "Desayuno", "Comida", "Comida", "Comida",
        "Desayuno", "Todo el día", "Comida"
    ]
})

# %%
df_alimentos_macros = df_alimentos.merge(categorias_ref, on="categoria", how="left")

# %%
df_alimentos_macros
# Out:
#               alimento  kcal categoria macronutriente momento
# 0     Aceitunas negras   349  verduras             CH  Comida
# 1     Aceitunas verdes   132  verduras             CH  Comida
# 2              Acelgas    33  verduras             CH  Comida
# 3                 Ajos   169  verduras             CH  Comida
# 4           Alcachofas    64  verduras             CH  Comida
# ..                 ...   ...       ...            ...     ...
# 291  Aceite de girasol   900   Aceites          Grasa  Comida
# 292    Aceite de oliva   900   Aceites          Grasa  Comida
# 293            Manteca   670   Aceites          Grasa  Comida
# 294        Mantequilla   752   Aceites          Grasa  Comida
# 295  Margarina vegetal   752   Aceites          Grasa  Comida
#
# [296 rows x 5 columns]

# %%
import pandas as pd
import numpy as np

# Definir alimentos con su categoría, macronutriente y kcal por 100g
alimentos = [
    ("Arroz", "Cereales", "CH", 130),
    ("Pan integral", "Cereales", "CH", 250),
    ("Pasta", "Cereales", "CH", 150),
    ("Pollo", "Carnes", "Proteína", 165),
    ("Carne de res", "Carnes", "Proteína", 250),
    ("Pescado", "Carnes", "Proteína", 200),
    ("Huevo", "Huevos", "Proteína", 155),
    ("Leche", "Lácteos", "Proteína", 60),
    ("Yogur", "Lácteos", "Proteína", 80),
    ("Aceite de oliva", "Aceites", "Grasa", 900),
    ("Mantequilla", "Aceites", "Grasa", 752),
    ("Almendras", "Frutos secos", "Grasa", 576),
    ("Manzana", "Frutas", "CH", 52),
    ("Plátano", "Frutas", "CH", 89),
    ("Zanahoria", "Verduras", "CH", 35),
    ("Brócoli", "Verduras", "CH", 55)
]

# Posibles momentos de consumo
momentos = ["Desayuno", "Comida", "Cena"]

# Generar comidas sintéticas
np.random.seed(42)
num_comidas = 300
datos = []

for comida_id in range(1, num_comidas + 1):
    num_alimentos = np.random.randint(2, 5)  # Cada comida tendrá de 2 a 4 alimentos
    indices_seleccionados = np.random.choice(len(alimentos), num_alimentos, replace=False)
    momento = np.random.choice(momentos)
    
    comida = []
    kcal_total = 0

    for idx in indices_seleccionados:
        alimento = alimentos[idx]
        cantidad = np.random.randint(50, 200)  # Cantidades entre 50g y 200g
        kcal = (cantidad / 100) * alimento[3]  # Calcular kcal totales
        kcal_total += kcal

        comida.append([comida_id, alimento[0], cantidad, kcal, alimento[2], alimento[1], momento])

    # Guardar la comida generada
    datos.extend(comida)

# Crear DataFrame
df_comidas = pd.DataFrame(datos, columns=["comida_id", "alimento", "cantidad (g)", "kcal", "macronutriente", "categoría", "momento"])

# Calcular kcal totales por comida
df_kcal_totales = df_comidas.groupby("comida_id")["kcal"].sum().reset_index()
df_kcal_totales.rename(columns={"kcal": "kcal_totales"}, inplace=True)

# Unir las kcal totales con el dataset principal
df_comidas = df_comidas.merge(df_kcal_totales, on="comida_id")

# Mostrar las primeras filas
df_comidas.head()
# Out:
#    comida_id      alimento  cantidad (g)    kcal macronutriente categoría  \
# 0          1         Arroz            51   66.30             CH  Cereales
# 1          1  Pan integral           137  342.50             CH  Cereales
# 2          1       Pescado            87  174.00       Proteína    Carnes
# 3          1       Brócoli           179   98.45             CH  Verduras
# 4          2  Pan integral            70  175.00             CH  Cereales
#
#     momento  kcal_totales
# 0  Desayuno        681.25
# 1  Desayuno        681.25
# 2  Desayuno        681.25
# 3  Desayuno        681.25
# 4      Cena        238.44

# %%
# Aumentar la cantidad de comidas generadas
num_comidas = 1000  # Más comidas para alcanzar más de 1000 filas
datos = []

for comida_id in range(1, num_comidas + 1):
    num_alimentos = np.random.randint(2, 5)  # Cada comida tendrá de 2 a 4 alimentos
    indices_seleccionados = np.random.choice(len(alimentos), num_alimentos, replace=False)
    momento = np.random.choice(momentos)

    comida = []
    kcal_total = 0

    for idx in indices_seleccionados:
        alimento = alimentos[idx]
        cantidad = np.random.randint(50, 200)  # Cantidades entre 50g y 200g
        kcal = (cantidad / 100) * alimento[3]  # Calcular kcal totales
        kcal_total += kcal

        comida.append([comida_id, alimento[0], cantidad, kcal, alimento[2], alimento[1], momento])

    # Guardar la comida generada
    datos.extend(comida)

# Crear DataFrame con más datos
df_comidas = pd.DataFrame(datos, columns=["comida_id", "alimento", "cantidad (g)", "kcal", "macronutriente", "categoría", "momento"])

# Calcular kcal totales por comida
df_kcal_totales = df_comidas.groupby("comida_id")["kcal"].sum().reset_index()
df_kcal_totales.rename(columns={"kcal": "kcal_totales"}, inplace=True)

# Unir las kcal totales con el dataset principal
df_comidas = df_comidas.merge(df_kcal_totales, on="comida_id")

# Verificar número de filas generadas
df_comidas.shape
# Out:
# (2990, 8)

# %%
df_comidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2990 entries, 0 to 2989
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   comida_id       2990 non-null   int64
#  1   alimento        2990 non-null   object
#  2   cantidad (g)    2990 non-null   int64
#  3   kcal            2990 non-null   float64
#  4   macronutriente  2990 non-null   object
#  5   categoría       2990 non-null   object
#  6   momento         2990 non-null   object
#  7   kcal_totales    2990 non-null   float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 187.0+ KB

# %%
df_comidas["alimento"].unique()
# Out:
# array(['Pasta', 'Manzana', 'Arroz', 'Leche', 'Huevo', 'Zanahoria',
#        'Mantequilla', 'Pescado', 'Pollo', 'Carne de res',
#        'Aceite de oliva', 'Brócoli', 'Almendras', 'Pan integral',
#        'Plátano', 'Yogur'], dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import pandas as pd

# Convertir las columnas categóricas a variables dummy (One-Hot Encoding)
df_comidas_dummies = pd.get_dummies(df_comidas[["macronutriente", "categoría", "momento"]])

# Añadir la cantidad como característica
df_comidas_dummies["cantidad (g)"] = df_comidas["cantidad (g)"]

# Normalizar las características
scaler = StandardScaler()
X = df_comidas_dummies
X_normalizado = scaler.fit_transform(X)

# Verificar la forma del conjunto de datos preprocesados
X_normalizado[:5]
# Out:
# array([[ 1.14953407, -0.46416285, -0.80291   , -0.35222173, -0.47899978,
#          2.11807425, -0.37579432, -0.26773978, -0.26558139, -0.40257624,
#         -0.37753094,  1.42241197, -0.74489073, -0.67400308,  1.37335176],
#        [ 1.14953407, -0.46416285, -0.80291   , -0.35222173, -0.47899978,
#         -0.47212698,  2.66103008, -0.26773978, -0.26558139, -0.40257624,
#         -0.37753094,  1.42241197, -0.74489073, -0.67400308, -0.18209074],
#        [ 1.14953407, -0.46416285, -0.80291   , -0.35222173, -0.47899978,
#          2.11807425, -0.37579432, -0.26773978, -0.26558139, -0.40257624,
#         -0.37753094,  1.42241197, -0.74489073, -0.67400308,  1.65193848],
#        [-0.86991767, -0.46416285,  1.24546961, -0.35222173, -0.47899978,
#         -0.47212698, -0.37579432, -0.26773978, -0.26558139,  2.48400157,
#         -0.37753094, -0.7030312 ,  1.34247879, -0.67400308,  0.72331609],
#        [-0.86991767, -0.46416285,  1.24546961, -0.35222173, -0.47899978,
#         -0.47212698, -0.37579432, -0.26773978,  3.76532402, -0.40257624,
#         -0.37753094, -0.7030312 ,  1.34247879, -0.67400308,  0.28222046]])

# %%
def generar_menu_por_comida(target_kcal_total, num_clusters, df_comidas, df_comidas_dummies):
    # Distribuir el total de kcal entre desayuno, comida y cena
    target_kcal_desayuno = target_kcal_total * 0.25
    target_kcal_comida = target_kcal_total * 0.50
    target_kcal_cena = target_kcal_total * 0.25

    # Inicializar los menús vacíos
    menu_desayuno = []
    menu_comida = []
    menu_cena = []

    # Función para generar un menú por comida ajustado a kcal específicas
    def generar_menu_comida(target_kcal):
        menu = []
        total_kcal = 0
        selected_foods = []

        # Dividir el DataFrame por clusters
        for cluster_id in range(num_clusters):
            cluster_data = df_comidas[df_comidas["cluster"] == cluster_id]

            # Seleccionar un alimento aleatorio del cluster
            alimento_seleccionado = cluster_data.sample(1).iloc[0]
            alimento = alimento_seleccionado["alimento"]
            categoria = alimento_seleccionado["categoría"]
            cantidad = alimento_seleccionado["cantidad (g)"]
            kcal = alimento_seleccionado["kcal"]

            # Añadir al menú
            menu.append([alimento, categoria, cantidad, kcal])
            selected_foods.append(alimento)
            total_kcal += kcal

        # Ajustar las cantidades de los alimentos para acercarse al objetivo calórico
        if total_kcal > target_kcal:
            # Reducir las cantidades proporcionalmente
            factor = target_kcal / total_kcal
            for i in range(len(menu)):
                menu[i][2] = menu[i][2] * factor
                menu[i][3] = (menu[i][2] / 100) * df_comidas[df_comidas["alimento"] == menu[i][0]]["kcal"].values[0]
        elif total_kcal < target_kcal:
            # Aumentar las cantidades proporcionalmente
            factor = target_kcal / total_kcal
            for i in range(len(menu)):
                menu[i][2] = menu[i][2] * factor
                menu[i][3] = (menu[i][2] / 100) * df_comidas[df_comidas["alimento"] == menu[i][0]]["kcal"].values[0]

        # Calcular el total final de kcal
        total_kcal_final = sum([item[3] for item in menu])

        return menu, total_kcal_final

    # Generar el menú para cada comida
    menu_desayuno, kcal_desayuno = generar_menu_comida(target_kcal_desayuno)
    menu_comida, kcal_comida = generar_menu_comida(target_kcal_comida)
    menu_cena, kcal_cena = generar_menu_comida(target_kcal_cena)

    # Devolver los menús con las kcal finales
    return {
        "Desayuno": {"menu": menu_desayuno, "total_kcal": kcal_desayuno},
        "Comida": {"menu": menu_comida, "total_kcal": kcal_comida},
        "Cena": {"menu": menu_cena, "total_kcal": kcal_cena}
    }

# Generar un menú ajustado a 2000 kcal y dividido por comida
menú_diario = generar_menu_por_comida(2000, 5, df_comidas, df_comidas_dummies)

# Mostrar los menús generados
for comida, info in menú_diario.items():
    print(f"\n{comida}: {info['total_kcal']:.1f} kcal")
    for item in info['menu']:
        print(f"{item[0]} ({item[1]}): {item[2]:.1f}g - {item[3]:.1f} kcal")
# Out:
# Desayuno: 425.0 kcal
# Manzana (Frutas): 83.9g - 51.1 kcal
# Pollo (Carnes): 65.2g - 85.0 kcal
# Mantequilla (Aceites): 35.2g - 140.1 kcal
# Pasta (Cereales): 40.8g - 112.7 kcal
# Leche (Lácteos): 38.6g - 36.1 kcal
#
# Comida: 1692.5 kcal
# Manzana (Frutas): 220.4g - 134.1 kcal
# Huevo (Huevos): 110.8g - 235.3 kcal
# Almendras (Frutos secos): 64.4g - 716.3 kcal
# Pasta (Cereales): 172.7g - 476.6 kcal
# Leche (Lácteos): 139.2g - 130.3 kcal
#
# Cena: 409.0 kcal
# Plátano (Frutas): 39.7g - 55.5 kcal
# Pescado (Carnes): 42.2g - 132.5 kcal
# Mantequilla (Aceites): 47.1g - 187.8 kcal
# Zanahoria (Verduras): 24.9g - 6.4 kcal
# Leche (Lácteos): 28.6g - 26.8 kcal
